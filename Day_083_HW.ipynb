# %% [markdown]
# ## Work
# 1. 試比較有 BN 在 Batch_size = 2, 16, 32, 128, 256 下的差異
# 2. 請嘗試將 BN 放在 Activation 之前，並比較訓練結果
# 3. 請於 BN 放在 Input Layer 後，並比較結果

# %%
import os
import tensorflow as tf
import itertools
# Disable GPU
os.environ["CUDA_VISIBLE_DEVICES"] = ""

# %%
train, test = tf.keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = tf.keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
from tensorflow.keras.layers import BatchNormalization
def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128]):
    input_layer = tf.keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = tf.keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(input_layer)
            x = BatchNormalization()(x)
        else:
            x = tf.keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(x)
            x = BatchNormalization()(x)
    
    out = tf.keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = tf.keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
## 超參數設定
LEARNING_RATE = 1e-3
EPOCHS = 10
BATCH_SIZE = [2, 16, 32, 128, 256]
MOMENTUM = 0.95

# %% [markdown]
# ### Normal batch normalization

# %%
results = {}
for batch in BATCH_SIZE:
    tf.keras.backend.clear_session() 
    print("Experiment with batch_size = %.6f" % (batch))
    model = build_mlp(input_shape=x_train.shape[1:])
    model.summary()
    optimizer = tf.keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
    model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

    model.fit(x_train, y_train, 
              epochs=EPOCHS, 
              batch_size=batch, 
              validation_data=(x_test, y_test), 
              shuffle=True)
    
    # Collect results
    train_loss = model.history.history["loss"]
    valid_loss = model.history.history["val_loss"]
    train_acc = model.history.history["acc"]
    valid_acc = model.history.history["val_acc"]
    
    exp_name_tag = "exp-batch-%s" % str(batch)
    results[exp_name_tag] = {'train-loss': train_loss,
                             'valid-loss': valid_loss,
                             'train-acc': train_acc,
                             'valid-acc': valid_acc}
# Out:
# Experiment with batch_size = 2.000000
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_v1 (Batc (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_v1_1 (Ba (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_v1_2 (Ba (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 409s 8ms/sample - loss: 2.3050 - acc: 0.1509 - val_loss: 2.1838 - val_acc: 0.2162
# Epoch 2/10
# 50000/50000 [==============================] - 424s 8ms/sample - loss: 2.2362 - acc: 0.1666 - val_loss: 2.1694 - val_acc: 0.2304
# Epoch 3/10
# 50000/50000 [==============================] - 447s 9ms/sample - loss: 2.2361 - acc: 0.1667 - val_loss: 2.1464 - val_acc: 0.2166
# Epoch 4/10
# 50000/50000 [==============================] - 441s 9ms/sample - loss: 2.2297 - acc: 0.1694 - val_loss: 2.0997 - val_acc: 0.2451
# Epoch 5/10
# 50000/50000 [==============================] - 443s 9ms/sample - loss: 2.2273 - acc: 0.1722 - val_loss: 2.2609 - val_acc: 0.2283
# Epoch 6/10
# 50000/50000 [==============================] - 443s 9ms/sample - loss: 2.2367 - acc: 0.1663 - val_loss: 2.4087 - val_acc: 0.1997
# Epoch 7/10
# 50000/50000 [==============================] - 437s 9ms/sample - loss: 2.2312 - acc: 0.1655 - val_loss: 2.7658 - val_acc: 0.2283
# Epoch 8/10
# 50000/50000 [==============================] - 437s 9ms/sample - loss: 2.2351 - acc: 0.1666 - val_loss: 4.7888 - val_acc: 0.1910
# Epoch 9/10
# 50000/50000 [==============================] - 447s 9ms/sample - loss: 2.2464 - acc: 0.1632 - val_loss: 5.6780 - val_acc: 0.1636
# Epoch 10/10
# 50000/50000 [==============================] - 439s 9ms/sample - loss: 2.2469 - acc: 0.1611 - val_loss: 4.7767 - val_acc: 0.1993
# Experiment with batch_size = 16.000000
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_v1 (Batc (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_v1_1 (Ba (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_v1_2 (Ba (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 64s 1ms/sample - loss: 1.8065 - acc: 0.3605 - val_loss: 1.6974 - val_acc: 0.3932
# Epoch 2/10
# 50000/50000 [==============================] - 61s 1ms/sample - loss: 1.6368 - acc: 0.4187 - val_loss: 1.6073 - val_acc: 0.4323
# Epoch 3/10
# 50000/50000 [==============================] - 60s 1ms/sample - loss: 1.5928 - acc: 0.4322 - val_loss: 1.5382 - val_acc: 0.4595
# Epoch 4/10
# 50000/50000 [==============================] - 61s 1ms/sample - loss: 1.5482 - acc: 0.4529 - val_loss: 1.5214 - val_acc: 0.4598
# Epoch 5/10
# 50000/50000 [==============================] - 58s 1ms/sample - loss: 1.5145 - acc: 0.4630 - val_loss: 1.5215 - val_acc: 0.4625
# Epoch 6/10
# 50000/50000 [==============================] - 53s 1ms/sample - loss: 1.4920 - acc: 0.4711 - val_loss: 1.5411 - val_acc: 0.4560
# Epoch 7/10
# 50000/50000 [==============================] - 54s 1ms/sample - loss: 1.4819 - acc: 0.4735 - val_loss: 1.4323 - val_acc: 0.4860
# Epoch 8/10
# 50000/50000 [==============================] - 54s 1ms/sample - loss: 1.4545 - acc: 0.4834 - val_loss: 1.5940 - val_acc: 0.4418
# Epoch 9/10
# 50000/50000 [==============================] - 54s 1ms/sample - loss: 1.4470 - acc: 0.4864 - val_loss: 1.6333 - val_acc: 0.4387
# Epoch 10/10
# 50000/50000 [==============================] - 55s 1ms/sample - loss: 1.4114 - acc: 0.4985 - val_loss: 1.4318 - val_acc: 0.4898
# Experiment with batch_size = 32.000000
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_v1 (Batc (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_v1_1 (Ba (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_v1_2 (Ba (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 30s 608us/sample - loss: 1.7328 - acc: 0.3902 - val_loss: 1.5835 - val_acc: 0.4314
# Epoch 2/10
# 50000/50000 [==============================] - 29s 579us/sample - loss: 1.5357 - acc: 0.4546 - val_loss: 1.5411 - val_acc: 0.4507
# Epoch 3/10
# 50000/50000 [==============================] - 28s 566us/sample - loss: 1.4642 - acc: 0.4816 - val_loss: 1.5253 - val_acc: 0.4569
# Epoch 4/10
# 50000/50000 [==============================] - 28s 567us/sample - loss: 1.4165 - acc: 0.4971 - val_loss: 1.5540 - val_acc: 0.4438
# Epoch 5/10
# 50000/50000 [==============================] - 28s 561us/sample - loss: 1.3858 - acc: 0.5077 - val_loss: 1.5403 - val_acc: 0.4534
# Epoch 6/10
# 50000/50000 [==============================] - 28s 569us/sample - loss: 1.3560 - acc: 0.5169 - val_loss: 1.5232 - val_acc: 0.4595
# Epoch 7/10
# 50000/50000 [==============================] - 28s 558us/sample - loss: 1.3143 - acc: 0.5314 - val_loss: 1.4970 - val_acc: 0.4701
# Epoch 8/10
# 50000/50000 [==============================] - 28s 560us/sample - loss: 1.2956 - acc: 0.5388 - val_loss: 1.4985 - val_acc: 0.4678
# Epoch 9/10
# 50000/50000 [==============================] - 28s 564us/sample - loss: 1.2727 - acc: 0.5471 - val_loss: 1.4375 - val_acc: 0.4943
# Epoch 10/10
# 50000/50000 [==============================] - 28s 564us/sample - loss: 1.2415 - acc: 0.5582 - val_loss: 1.4113 - val_acc: 0.4928
# Experiment with batch_size = 128.000000
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_v1 (Batc (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_v1_1 (Ba (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_v1_2 (Ba (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 12s 245us/sample - loss: 1.7651 - acc: 0.3837 - val_loss: 1.6720 - val_acc: 0.4120
# Epoch 2/10
# 50000/50000 [==============================] - 11s 217us/sample - loss: 1.4982 - acc: 0.4727 - val_loss: 1.5732 - val_acc: 0.4410
# Epoch 3/10
# 50000/50000 [==============================] - 11s 226us/sample - loss: 1.3970 - acc: 0.5101 - val_loss: 1.5497 - val_acc: 0.4559
# Epoch 4/10
# 50000/50000 [==============================] - 11s 228us/sample - loss: 1.3261 - acc: 0.5314 - val_loss: 1.4848 - val_acc: 0.4761
# Epoch 5/10
# 50000/50000 [==============================] - 11s 226us/sample - loss: 1.2680 - acc: 0.5556 - val_loss: 1.4709 - val_acc: 0.4812
# Epoch 6/10
# 50000/50000 [==============================] - 11s 226us/sample - loss: 1.2139 - acc: 0.5730 - val_loss: 1.5020 - val_acc: 0.4748
# Epoch 7/10
# 50000/50000 [==============================] - 9s 182us/sample - loss: 1.1664 - acc: 0.5888 - val_loss: 1.5526 - val_acc: 0.4601
# Epoch 8/10
# 50000/50000 [==============================] - 9s 175us/sample - loss: 1.1272 - acc: 0.6029 - val_loss: 1.4989 - val_acc: 0.4747
# Epoch 9/10
# 50000/50000 [==============================] - 9s 170us/sample - loss: 1.0858 - acc: 0.6177 - val_loss: 1.5506 - val_acc: 0.4669
# Epoch 10/10
# 50000/50000 [==============================] - 9s 172us/sample - loss: 1.0499 - acc: 0.6311 - val_loss: 1.6140 - val_acc: 0.4618
# Experiment with batch_size = 256.000000
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_v1 (Batc (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_v1_1 (Ba (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_v1_2 (Ba (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 7s 141us/sample - loss: 1.8670 - acc: 0.3600 - val_loss: 1.7524 - val_acc: 0.3821
# Epoch 2/10
# 50000/50000 [==============================] - 6s 126us/sample - loss: 1.5532 - acc: 0.4573 - val_loss: 1.5820 - val_acc: 0.4443
# Epoch 3/10
# 50000/50000 [==============================] - 6s 125us/sample - loss: 1.4498 - acc: 0.4921 - val_loss: 1.6123 - val_acc: 0.4319
# Epoch 4/10
# 50000/50000 [==============================] - 6s 125us/sample - loss: 1.3757 - acc: 0.5176 - val_loss: 1.6297 - val_acc: 0.4266
# Epoch 5/10
# 50000/50000 [==============================] - 6s 124us/sample - loss: 1.3165 - acc: 0.5397 - val_loss: 1.5041 - val_acc: 0.4674
# Epoch 6/10
# 50000/50000 [==============================] - 6s 125us/sample - loss: 1.2639 - acc: 0.5589 - val_loss: 1.5148 - val_acc: 0.4719
# Epoch 7/10
# 50000/50000 [==============================] - 6s 125us/sample - loss: 1.2157 - acc: 0.5767 - val_loss: 1.5428 - val_acc: 0.4637
# Epoch 8/10
# 50000/50000 [==============================] - 6s 125us/sample - loss: 1.1697 - acc: 0.5933 - val_loss: 1.4899 - val_acc: 0.4813
# Epoch 9/10
# 50000/50000 [==============================] - 6s 125us/sample - loss: 1.1256 - acc: 0.6088 - val_loss: 1.4820 - val_acc: 0.4889
# Epoch 10/10
# 50000/50000 [==============================] - 6s 125us/sample - loss: 1.0938 - acc: 0.6185 - val_loss: 1.4629 - val_acc: 0.4869

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
color_bar = ["r", "g", "b", "y", "m", "k"]

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-loss'])),results[cond]['train-loss'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-loss'])),results[cond]['valid-loss'], '--', label=cond, color=color_bar[i])
plt.title("Loss")
plt.legend()
plt.show()

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-acc'])),results[cond]['train-acc'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-acc'])),results[cond]['valid-acc'], '--', label=cond, color=color_bar[i])
plt.title("Accuracy")
plt.legend()
plt.show()
